# %%
user_id = {}
hotel_id = {}
k = 0 
with open('uid_hotel_rat','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()
#         data({i[1]:[{i[0]:i[2]}]})
        user_id[i[0]]=[]
        hotel_id[i[1]] = []
count = 1
for i in user_id:
    user_id[i] = count
    count+=1

count = 1
for i in hotel_id:
    hotel_id[i] = count
    count+=1

with open('uid_hotel_rat','r',encoding='utf-8') as f:
    with open('giveid','a+',encoding='utf-8') as g:
        for j in f:
            i = j.split()
#             print(user_id[i[0]],hotel_id[i[1]],i[2])
            g.write(str(user_id[i[0]])+' '+str(hotel_id[i[1]])+' '+i[2]+'\n')
#             break
    #         data[i[0]].append({i[1]:i[2]})

# %%
hotel_id = {}
with open('uid_hotel_rat','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()
        hotel_id[i[1]] = []
count = 1
for i in hotel_id:
    hotel_id[i] = count
    count+=1
with open('city_hotelname_hid_hurl','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()
        if i[-2] in hotel_id.keys():
            with open('givehotel','a+',encoding='utf-8') as g:
                g.write(str(hotel_id[i[-2]])+' '+\
                        i[0]+' '+''.join(i[1:-2])+' '+\
                        i[-2]+' '+i[-1]+'\n')
            del hotel_id[i[-2]]
#             print(hotel_id[i[-2]],i[0],''.join(i[1:-2]),i[-2],i[-1])

# %%
user_id = {}
with open('uid_hotel_rat','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()
        user_id[i[0]] = []
count = 1
for i in user_id:
    user_id[i] = count
    count+=1

with open('trust_u_u','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()

# %%
len(user_id)
# Out:
# 171932

# %%
#creat trust rating data by trust relate
count = 0
trust_data = []
with open('trust_u_u1','r',encoding='utf-8') as f:
    for j in f:
        i = j.split()
        if i[0] in user_id.keys() and i[1] in user_id.keys()  :
            count+=1
            trust_data.append((user_id[i[0]],user_id[i[1]]))
#             print(user_id[i[0]],user_id[i[1]])
# print(count)
for i in trust_data:
    trust1 = {}
    trust2 = {}
#         print(i)
    with open('giveid','r',encoding='utf-8') as f:
        for j in f:
            k = j.split()
            if int(k[0]) == i[0]:
                trust1[k[1]] = k[2]
#                 trust1.add(k[1])
#                 print(i[0],k[0],k[1],k[2])
            if int(k[0]) == i[1]:
                trust2[k[1]] = k[2]
#                 trust2.add(k[1])
#                 print(i[1],k[0],k[1],k[2])
        
        for j in set(trust2.keys())-set(trust1.keys()):
            print(i[0],j,trust2[j])
            with open('trust_giveid1','a+',encoding='utf-8') as g:
                g.write(str(i[0])+' '+j+' '+str(trust2[j])+'\n')





# for i in trust_data:
#     trust1 = set()
#     trust2 = set()
# #         print(i)
#     with open('giveid','r',encoding='utf-8') as f:
#         for j in f:
#             k = j.split()
#             if int(k[0]) == i[0]:
#                 trust1.add(k[1])
#                 print(i[0],k[0],k[1],k[2])
#             if int(k[0]) == i[1]:
#                 trust2.add(k[1])
#                 print(i[1],k[0],k[1],k[2])
                
#         for j in trust2-trust1:
#             print(i[0],j,)
        

            
        
#     for j in f:
#         i = j.split()
#         print(i[0],i[1],i[2])
#         break
#     for i in trust_data:
# Out:
# 132604 1 5
# 55214 1156 4
# 55214 1 4
# 55214 796 3
# 55214 649 4
# 210 6037 5
# 7610 1 4
# 7610 797 4
# 7610 15 4
# 7610 446 5
# 7610 40 5
# 7610 442 5
# 7610 13 5
# 7610 25 5
# 7610 450 5
# 7610 796 4
# 7610 1 5
# 7610 4114 5
# 7610 726 5
# 7610 653 5
# 7610 4115 5
# 5390 1 5
# 5390 1511 2
# 5390 1719 5
# 5390 2244 3
# 7610 494 3
# 7610 493 4
# 7610 207 4
# 7610 4130 4
# 7610 294 5
# 7610 1 4
# 7610 176 3
# 7610 315 3
# 7610 4121 4
# 7610 4127 3
# 7610 318 5
# 169598 494 3
# 169598 493 4
# 169598 207 4
# 169598 4130 4
# 169598 318 5
# 169598 294 5
# 169598 1 4
# 169598 315 3
# 169598 4121 4
# 169598 4127 3
# 169598 176 3
# 343 2520 5
# 90128 1 5
# 371 1713 5
# 371 5 5
# 72480 1 5
# 72480 200 4
# 72480 443 4
# 55715 1 5
# 55715 200 4
# 55715 443 4
# 609 1508 5
# 750 4482 5
# 750 1433 4
# 1232 442 5
# 36260 2243 4
# 36260 2 4
# 75497 10 5
# 75497 1196 5
# 75497 1563 3
# 75497 1230 5
# 75497 3 5
# 75497 1442 5
# 75497 3426 5
# 75497 846 5
# 75497 1430 5
# 75497 1432 5
# 75497 4160 5
# ...

# %%
emptyset = set()
a = {2,5,6}
b = {2,3,4}
b - a

# %%
c = {'a':1,'b':2}
set(c.keys())
# Out:
# {'a', 'b'}
